# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
articles_df = pd.read_csv('data/articles_metadata.csv')
clicks_df = pd.read_csv('data/clicks_sample.csv')
clicks_by_hour_df = pd.read_csv('data/clicks/clicks_hour_000.csv')

# %% [markdown]
# ## Articles

# %%
articles_df.describe()
# Out:
#           article_id    category_id  created_at_ts  publisher_id  \
# count  364047.000000  364047.000000   3.640470e+05      364047.0
# mean   182023.000000     283.108239   1.474070e+12           0.0
# std    105091.461061     136.723470   4.293038e+10           0.0
# min         0.000000       0.000000   1.159356e+12           0.0
# 25%     91011.500000     199.000000   1.444925e+12           0.0
# 50%    182023.000000     301.000000   1.489422e+12           0.0
# 75%    273034.500000     399.000000   1.509891e+12           0.0
# max    364046.000000     460.000000   1.520943e+12           0.0
#
#          words_count
# count  364047.000000
# mean      190.897727
# std        59.502766
# min         0.000000
# 25%       159.000000
# 50%       186.000000
# 75%       218.000000
# max      6690.000000

# %%
print("Nombre d'articles :",len(articles_df.article_id.unique()))
# Out:
# Nombre d'articles : 364047

# %%
articles_df.head(10)
# Out:
#    article_id  category_id  created_at_ts  publisher_id  words_count
# 0           0            0  1513144419000             0          168
# 1           1            1  1405341936000             0          189
# 2           2            1  1408667706000             0          250
# 3           3            1  1408468313000             0          230
# 4           4            1  1407071171000             0          162
# 5           5            1  1407413929000             0          196
# 6           6            1  1409896802000             0          203
# 7           7            1  1412559620000             0          154
# 8           8            1  1414351550000             0          209
# 9           9            1  1412526792000             0          181

# %%
print("Nombre de catégories :",len(articles_df.category_id.unique()))
# Out:
# Nombre de catégories : 461

# %%
print("Editeur :",len(articles_df.publisher_id.unique()))
# Out:
# Editeur : 1

# %% [markdown]
# ## Nombre de mots par article

# %% [markdown]
# Présence d'un valeur max de + de 6000 mots

# %%
plt.hist(articles_df.words_count,bins = 100);

# %%
plt.hist(articles_df.words_count,bins = 1000);
plt.xlim((0,600));

# %% [markdown]
# ## Clicks

# %%
clicks_df.describe()
# Out:
#            user_id    session_id  session_start  session_size  \
# count  1883.000000  1.883000e+03   1.883000e+03   1883.000000
# mean    355.893787  1.506828e+15   1.506828e+12      3.459904
# std     206.162865  8.679628e+08   8.679468e+05      3.037467
# min       0.000000  1.506825e+15   1.506825e+12      2.000000
# 25%     181.500000  1.506827e+15   1.506827e+12      2.000000
# 50%     353.000000  1.506828e+15   1.506828e+12      3.000000
# 75%     537.000000  1.506828e+15   1.506828e+12      4.000000
# max     706.000000  1.506829e+15   1.506829e+12     24.000000
#
#        click_article_id  click_timestamp  click_environment  \
# count       1883.000000     1.883000e+03        1883.000000
# mean      176717.848646     1.506830e+12           3.917153
# std        82324.177259     1.064938e+07           0.410461
# min         2137.000000     1.506827e+12           1.000000
# 25%       108854.000000     1.506828e+12           4.000000
# ...

# %%
clicks_df
# Out:
#       user_id        session_id  session_start  session_size  \
# 0           0  1506825423271737  1506825423000             2
# 1           0  1506825423271737  1506825423000             2
# 2           1  1506825426267738  1506825426000             2
# 3           1  1506825426267738  1506825426000             2
# 4           2  1506825435299739  1506825435000             2
# ...       ...               ...            ...           ...
# 1878      705  1506828968165442  1506828968000             2
# 1879      705  1506828968165442  1506828968000             2
# 1880      706  1506828979881443  1506828979000             3
# 1881      706  1506828979881443  1506828979000             3
# 1882      706  1506828979881443  1506828979000             3
#
#       click_article_id  click_timestamp  click_environment  click_deviceGroup  \
# 0               157541    1506826828020                  4                  3
# ...

# %%
clicks_df["click_article_id"].max()
# Out:
# 363291

# %% [markdown]
# ## Clicks by hour

# %%
clicks_by_hour_df
# Out:
#       user_id        session_id  session_start  session_size  \
# 0           0  1506825423271737  1506825423000             2
# 1           0  1506825423271737  1506825423000             2
# 2           1  1506825426267738  1506825426000             2
# 3           1  1506825426267738  1506825426000             2
# 4           2  1506825435299739  1506825435000             2
# ...       ...               ...            ...           ...
# 1878      705  1506828968165442  1506828968000             2
# 1879      705  1506828968165442  1506828968000             2
# 1880      706  1506828979881443  1506828979000             3
# 1881      706  1506828979881443  1506828979000             3
# 1882      706  1506828979881443  1506828979000             3
#
#       click_article_id  click_timestamp  click_environment  click_deviceGroup  \
# 0               157541    1506826828020                  4                  3
# ...

# %% [markdown]
# ## Articles embeddings

# %%
articles_emb = pickle.load(open("data/articles_embeddings.pickle","rb"))

# %%
articles_emb
# Out:
# array([[-0.16118301, -0.95723313, -0.13794445, ..., -0.231686  ,
#          0.5974159 ,  0.40962312],
#        [-0.52321565, -0.974058  ,  0.73860806, ...,  0.18282819,
#          0.39708954, -0.83436364],
#        [-0.61961854, -0.9729604 , -0.20736018, ..., -0.44758022,
#          0.8059317 , -0.28528407],
#        ...,
#        [-0.25139043, -0.9762427 ,  0.58609664, ..., -0.14372464,
#          0.06809307, -0.7050104 ],
#        [ 0.22434181, -0.92328775, -0.38174152, ...,  0.6871319 ,
#         -0.5315117 ,  0.01072566],
#        [-0.25713393, -0.9946313 ,  0.9837918 , ...,  0.98387307,
#         -0.8381829 , -0.1792827 ]], dtype=float32)

# %%
articles_emb.shape
# Out:
# (364047, 250)

# %%
from sklearn.manifold import TSNE

def tsne_plot(emb,art_categories):
    "Creates and TSNE model and plots it"
 
 
    
    tsne_model = TSNE(perplexity=10, n_components=2, init='pca', n_iter=2500, random_state=0)
    new_values = tsne_model.fit_transform(emb)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    fig = plt.figure(figsize=(15,15))
    plt.scatter( x=x, y=y ,c=art_categories)
    
    plt.show()

# %%
emb = articles_emb[::100]
art_categories = articles_df[::100].category_id

tsne_plot(emb,art_categories)

# %% [markdown]
# ## Modélisation : content filtering
# Nous allons utiliser ici en mesure de produit scalaire
# Au niveau du contenu nous allons utiliser la catégorie de l'article en one hot vector concaténée avec le nombre de mots
#
# Pour utilisateur, nous utiliserons la catégorie la plus cliquée ainsi que la longueur moyenne des articles
